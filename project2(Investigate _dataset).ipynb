# %% [markdown]
# Introduction
#
# welcome to the investigate a dataset you will fined som answers to help you for clear the (movies)
#
# project:Investigate a Dataset (TMDb movie data)

# %%
#install the packages we need 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from collections import Counter

# %% [markdown]
# General Properties

# %%
df = pd.read_csv("/Users/Ghyda/OneDrive/Documents/dataset1-movies.csv")
df.head(10)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
# 5  281957  tt1663202    9.110700  135000000   532950503
# 6   87101  tt1340138    8.654359  155000000   440603537
# 7  286217  tt3659388    7.667400  108000000   595380321
# 8  211672  tt2293640    7.404165   74000000  1156730962
# 9  150540  tt2096673    6.326804  175000000   853708609
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
# 5                  The Revenant
# 6            Terminator Genisys
# 7                   The Martian
# 8                       Minions
# ...

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# ...

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df.shape
# Out:
# (10866, 19)

# %% [markdown]
# Data Cleaning

# %%
df.rename(columns=lambda x: x.strip().lower().replace("release_date ", "year_release"), inplace=True)
df.head(10)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
# 5  281957  tt1663202    9.110700  135000000   532950503
# 6   87101  tt1340138    8.654359  155000000   440603537
# 7  286217  tt3659388    7.667400  108000000   595380321
# 8  211672  tt2293640    7.404165   74000000  1156730962
# 9  150540  tt2096673    6.326804  175000000   853708609
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
# 5                  The Revenant
# 6            Terminator Genisys
# 7                   The Martian
# 8                       Minions
# ...

# %%
df.fillna(df, method=None, axis='columns', inplace=False, limit=None, downcast=None)
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
pd.isna
# Out:
# <function pandas.core.dtypes.missing.isna(obj)>

# %%
np.where(pd.isnull(df))
# Out:
# (array([   18,    21,    26, ..., 10863, 10864, 10865], dtype=int64),
#  array([7, 7, 7, ..., 9, 7, 7], dtype=int64))

# %%
column_1 = df["revenue"]
column_2 = df["vote_average"]
correlation = column_1.corr(column_2)
print(correlation)
# Out:
# 0.1725637468027009

# %%
df[df.director.isnull()].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E97DD39588>,
# ...
#       dtype=object)

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9767AC488>,
# ...
#       dtype=object)

# %%
df.isnull().sum().sum()
# Out:
# 13434

# %%
df.dropna()
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10724     668  tt0064757    1.778746    7000000    81974493
# 10759     948  tt0077651    1.198849     300000    70000000
# 10760    8469  tt0077975    1.157930    2700000   141000000
# 10817   13963  tt0077838    0.064029          0      321952
# 10819   16214  tt0077696    0.044675          0    78000000
#
#                         original_title  \
# 0                       Jurassic World
# 1                   Mad Max: Fury Road
# 2                            Insurgent
# 3         Star Wars: The Force Awakens
# 4                            Furious 7
# ...

# %%
df = pd.DataFrame(
    np.random.randint(1, 7, 6000),
    columns = ['vote_average'])
df['original_title'] = df['vote_average'] + np.random.randint(1, 9, 6000)
ax = df.plot.hist(bins=12, alpha=0.5)

# %%
num_vars=df.columns[df.dtypes != 'object']
len(df)
# Out:
# 10866

# %%
df[num_vars].isnull().sum().sort_values(ascending=False)/len(df)
# Out:
# revenue_adj     0.0
# budget_adj      0.0
# release_year    0.0
# vote_average    0.0
# vote_count      0.0
# runtime         0.0
# revenue         0.0
# budget          0.0
# popularity      0.0
# id              0.0
# dtype: float64

# %%
n=df['revenue'].value_counts()
n
# Out:
# 0            6016
# 12000000       10
# 10000000        8
# 11000000        7
# 6000000         6
#              ...
# 53676580        1
# 617000          1
# 13001257        1
# 504050219       1
# 20518905        1
# Name: revenue, Length: 4702, dtype: int64

# %%
n.index
# Out:
# Int64Index([        0,  12000000,  10000000,  11000000,   6000000,   5000000,
#               2000000,  13000000,  20000000,  14000000,
#             ...
#              39946780,   3117985,     22270,  65884703,   4500000,  53676580,
#                617000,  13001257, 504050219,  20518905],
#            dtype='int64', length=4702)

# %%
df.revenue.describe()
# Out:
# count    1.086600e+04
# mean     3.982332e+07
# std      1.170035e+08
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.400000e+07
# max      2.781506e+09
# Name: revenue, dtype: float64

# %%
df.rename(columns=lambda x: x.strip().lower().replace("release_date ", "year_release"), inplace=True)
df.head(10)
# Out:
#    vote_average  original_title
# 0             3               6
# 1             1               7
# 2             4               8
# 3             2               5
# 4             6               7
# 5             1               2
# 6             5               9
# 7             5              10
# 8             6              12
# 9             4               7

# %%
plt.scatter(df['revenue'], df['budget'],alpha=0.5)
plt.title('Relationship')
plt.xlabel('genres_movies')
plt.ylabel('revenue_movies')
plt.show()

# %%
df.boxplot(column=['release_year','revenue'])

# %%
df['revenue'].max()
# Out:
# <bound method Series.mean of 0        1513528810
# 1         378436354
# 2         295238201
# 3        2068178225
# 4        1506249360
#             ...
# 10861             0
# 10862             0
# 10863             0
# 10864             0
# 10865             0
# Name: revenue, Length: 10866, dtype: int64>

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# the question: 1-What is the all information of the movie with the highest return?

# %%
df. iloc[1386]
# Out:
# id                                                                  19995
# imdb_id                                                         tt0499549
# popularity                                                        9.43277
# budget                                                          237000000
# revenue                                                        2781505847
# original_title                                                     Avatar
# cast                    Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# homepage                                      http://www.avatarmovie.com/
# director                                                    James Cameron
# tagline                                       Enter the World of Pandora.
# keywords                culture clash|future|space war|space colony|so...
# overview                In the 22nd century, a paraplegic Marine is di...
# runtime                                                               162
# ...

# %% [markdown]
# the movie with the highest return is Avatar

# %% [markdown]
# 2-What is the name of the most frequent director?

# %%
df['director'].value_counts().head(1)
# Out:
# Woody Allen    45
# Name: director, dtype: int64

# %% [markdown]
# the most film director created is (Woody Allen)

# %% [markdown]
# 3-Which movie title had the highest budget?

# %%
df['budget'].max()
df.loc[df.budget ==425000000 , 'original_title']
# Out:
# 2244    The Warrior's Way
# Name: original_title, dtype: object

# %% [markdown]
# the movie highest budget is The Warrior's Way

# %% [markdown]
# 4-What are most frequent types of movies?

# %%
types=df['genres'].value_counts().idxmax() 
print("the most frequent types of movies is",types)
# Out:
# the most frequent types of movies is Drama

# %% [markdown]
# the are most geners is Drama

# %% [markdown]
#  Conclusions
#
# -We found 13434 null values
# -We found the relationship between the proceeds with the amount of donation and we got that it is a positive relationship
# -We removed the columns we didn't need (budget_adj ,revenue_adj)
# -the analysis and visualization in my project:
# 1-statistical analysis
# 2-average returns
# 3-sum the empty values
# 4-Number of rows and columns

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Investigate_a_Dataset.ipynb'])
# Out:
# 4294967295
